# %% [markdown]
# # DATA SCIENCE AND BUSINESS ANALYSIS FUNCTION
# ## TASK 6: Prediction using Decision Tree Algorithm

# %% [markdown]
# #### Install The Libraies Needed For This Task

# %%
pip install scikit-learn matplotlib

# %% [markdown]
# #### Load The Iris Dataset

# %%
from sklearn.datasets import load_iris

# Represent the iris dataset as data 
data = load_iris()

# To view the dataset remove the "#" symbol in front of data
#data

# Create variables for representing the data to be used for training
x, y = data.data, data.target

# %% [markdown]
# #### Train The Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

# Create an instance of the Decision Tree class
dtc: DecisionTreeClassifier = DecisionTreeClassifier()

# Train Decision Tree model
dtc.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# #### Basic Command Line Based Visualization

# %%
from sklearn import tree

# Visualization the decission tree classifier
print(tree.export_text(dtc))  # Not very appealing to the eyes
# Out:
# |--- feature_3 <= 0.80
# |   |--- class: 0
# |--- feature_3 >  0.80
# |   |--- feature_3 <= 1.75
# |   |   |--- feature_2 <= 4.95
# |   |   |   |--- feature_3 <= 1.65
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_3 >  1.65
# |   |   |   |   |--- class: 2
# |   |   |--- feature_2 >  4.95
# |   |   |   |--- feature_3 <= 1.55
# |   |   |   |   |--- class: 2
# |   |   |   |--- feature_3 >  1.55
# |   |   |   |   |--- feature_0 <= 6.95
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  6.95
# |   |   |   |   |   |--- class: 2
# |   |--- feature_3 >  1.75
# |   |   |--- feature_2 <= 4.85
# |   |   |   |--- feature_0 <= 5.95
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_0 >  5.95
# |   |   |   |   |--- class: 2
# |   |   |--- feature_2 >  4.85
# |   |   |   |--- class: 2

# %% [markdown]
# #### Visualization Through Matplotlib

# %%
import matplotlib.pyplot as plt

# Creating a blank canvas a.k.a figure
fig = plt.figure(figsize=(50,30))

# Create the visualization through a throw-away variable
# Note: Removing the throw-away variable initialization will display
#       the decission tree in list format alongside the visualization
_ = tree.plot_tree(dtc, feature_names=data.feature_names, class_names=data.target_names, filled=True)

# %% [markdown]
# NOTE: You could also use export export_graphviz for visualization but it is lot more complicated
#       By using export_graphviz, you are exporting a dot (.dot) file and you need convert that file
#       since it is a text-based file. One way is using the pydotplus library and the Image class in
#       IPython.display.
